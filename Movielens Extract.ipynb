# %%
import os
import pandas as pd
from sqlalchemy import create_engine
from config import password
import time

# %%
kaggle_movies = os.path.join("Resources", "movies_metadata.csv" )
kaggle_rating = os.path.join("Resources", "ratings.csv")

# %%
kaggle_metadata = pd.read_csv(kaggle_movies)
ratings = pd.read_csv(kaggle_rating)
# Out:
# C:\Users\Billy\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
# check datetypes
kaggle_metadata.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
# Check 'adult' boolean count

kaggle_metadata['adult'].value_counts()
# Out:
# False                                                                                                                             45454
# True                                                                                                                                  9
#  - Written by Ørnås                                                                                                                   1
#  Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.                        1
#  Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.        1
# Name: adult, dtype: int64

# %%
kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
# Out:
#                                                    adult  \
# 19730                                 - Written by Ørnås
# 29503   Rune Balot goes to a casino connected to the ...
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#       belongs_to_collection                            budget  \
# 19730              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                                   genres  \
# 19730  [{'name': 'Carousel Productions', 'id': 11176}...
# 29503  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 35587  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                                 homepage          id imdb_id  \
# 19730  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  1997-08-20       0
# 29503  [{'iso_3166_1': 'US', 'name': 'United States o...  2012-09-29       0
# ...

# %%
# drop all movies not adult = false and drop adult column

kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

# %%
kaggle_metadata
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %%
# video column

kaggle_metadata['video'].value_counts()
# Out:
# False    45358
# True        93
# Name: video, dtype: int64

# %%
# videos = true

kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

# %%
# set numberic columns

kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# %%
kaggle_metadata.dtypes
# Out:
# belongs_to_collection     object
# budget                     int32
# genres                    object
# homepage                  object
# id                         int64
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                       bool
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
# change date time of release date

kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

# %%
# check rating

ratings.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB
# C:\Users\Billy\AppData\Local\Temp/ipykernel_4108/2946422897.py:3: FutureWarning: null_counts is deprecated. Use show_counts instead
#   ratings.info(null_counts=True)

# %%
#ratings.value_counts()
# Out:
# userId  movieId  rating  timestamp
# 1       110      1.0     1425941529    1
# 180081  3422     3.0     952526895     1
#         3418     3.0     969375943     1
#         3408     4.0     969374639     1
#         3365     4.0     969375996     1
#                                       ..
# 89440   45186    4.0     1440610879    1
#         44022    5.0     1440609793    1
#         41566    4.0     1443114714    1
#         40815    3.0     1443114532    1
# 270896  71878    2.0     1257031858    1
# Length: 26024289, dtype: int64

# %%
# change rating timestamp column to date time

ratings['timestamp']= pd.to_datetime(ratings['timestamp'], unit='s')

# %%
# looking at ratings rating column with histogram and describe

pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
# open clean wiki data

wiki_data_clean = os.path.join("Resources", "clean_wiki_data.csv")

wiki_movies_df = pd.read_csv(wiki_data_clean)

wiki_movies_df
# Out:
#       Unnamed: 0                                                url  year  \
# 0              0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1              1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2              2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3              3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4              4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...          ...                                                ...   ...
# 7028        7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7029        7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7030        7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7031        7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7032        7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# ...

# %%
# merge dataframes

movies_df= pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])

movies_df
# Out:
#       Unnamed: 0                                                url  year  \
# 0              0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1              1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2              2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3              3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4              4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...          ...                                                ...   ...
# 6047        6837    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048        6844    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049        6849      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050        6888   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051        6925  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link                       title_wiki  \
# ...

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop Wiki
# running_time             runtime                  keep kaggle; fill in zeroes with wiki
# budget_wiki              budget_kaggle            keep kaggle; fill in zeroes with wiki
# box_office               revenue                  keep kaggle; fill in zeroes with wiki
# release_date_wiki        release_date_kaggle      Drop wiki
# Language                 original_language        Drop wiki
# Production company(s)    production_companies     Drop wiki

# %%
# compare titles
movies_df[['title_wiki','title_kaggle']]
# Out:
#                            title_wiki                     title_kaggle
# 0     The Adventures of Ford Fairlane  The Adventures of Ford Fairlane
# 1                After Dark, My Sweet             After Dark, My Sweet
# 2                         Air America                      Air America
# 3                               Alice                            Alice
# 4                     Almost an Angel                  Almost an Angel
# ...                               ...                              ...
# 6047                A Fantastic Woman                A Fantastic Woman
# 6048                       Permission                       Permission
# 6049                         Loveless                         Loveless
# 6050                           Gemini                           Gemini
# 6051  How to Talk to Girls at Parties  How to Talk to Girls at Parties
#
# [6052 rows x 2 columns]

# %%
# check how many titles don't match
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki', 'title_kaggle']]
# Out:
#                                            title_wiki  \
# 27                                          China Cry
# 36               Daddy's Dyin' ...Who's Got the Will?
# 38                          The Dark Side of the Moon
# 42                                      Delta Force 2
# 48      DuckTales the Movie:Treasure of the Lost Lamp
# ...                                               ...
# 5956                                            Chips
# 5971                                            Spark
# 5994  Pirates of the Caribbean:Dead Men Tell No Tales
# 6023       Valerian and the Cityof a Thousand Planets
# 6028            An Inconvenient Sequel:Truth to Power
#
#                                           title_kaggle
# 27                             China Cry: A True Story
# 36                Daddy's Dyin'... Who's Got the Will?
# 38                           The Dark Side of The Moon
# 42             Delta Force 2: The Colombian Connection
# ...

# %%
# Show any rows where title_kaggle is empty
movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 45 columns]

# %%
# plot runtime to check if they are close

movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')
# Out:
# <AxesSubplot:xlabel='running_time', ylabel='runtime'>

# %%
# plot budget to check if they are close

movies_df.fillna(0).plot(x= 'budget_wiki', y='budget_kaggle', kind= 'scatter')
# Out:
# <AxesSubplot:xlabel='budget_wiki', ylabel='budget_kaggle'>

# %%
# plot box office to check if they are close

movies_df.fillna(0).plot(x='box_office', y='revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
movies_df.fillna(0)[movies_df['box_office'] < 10**9].plot(x='box_office', y='revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
# plot release date to check if they are close

movies_df[['release_date_wiki','release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')
# Out:
# <AxesSubplot:xlabel='release_date_wiki'>

# %%
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]
# Out:
#       Unnamed: 0                                        url  year  \
# 3607        4092  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link   title_wiki Based on  \
# 3607  https://www.imdb.com/title/tt00457939/  The Holiday      NaN
#
#                                                Starring Cinematography  \
# 3607  ['Kate Winslet', 'Cameron Diaz', 'Jude Law', '...    Dean Cundey
#
#                                       Release date        Country  ...  \
# 3607  ['December 8, 2006', '(', '2006-12-08', ')']  United States  ...
#
#      release_date_kaggle              revenue              runtime  \
# 3607          1953-08-28        30,500,000.00               118.00
#
#                               spoken_languages    status  \
# 3607  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3607  Pouring out of impassioned pages...brawling th...
#
# ...

# %%
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index
# Out:
# Int64Index([3607], dtype='int64')

# %%
movies_df = movies_df.drop(movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index)

# %%
movies_df[movies_df['release_date_wiki'].isnull()]
# Out:
#       Unnamed: 0                                                url  year  \
# 1008        1173  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1061        1234    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1121        1302  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1564        1836  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1633        1922      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1775        2102        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2386        2764  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2786        3190   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3174        3609  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3651        4142  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4967        5583  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# ...

# %%
movies_df['Language'].value_counts()
# Out:
# English                              5479
# ['English', 'Spanish']                 68
# ['English', 'French']                  35
# ['English', 'Japanese']                25
# ['English', 'Russian']                 23
#                                      ...
# ['English /', 'Zulu']                   1
# ['English', 'Hebrew', 'Spanish']        1
# ['English', 'Japanese', 'French']       1
# ['English', 'Spanish', 'Apache']        1
# Russian                                 1
# Name: Language, Length: 197, dtype: int64

# %%
movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False)
# Out:
# English                              5479
# NaN                                   134
# ['English', 'Spanish']                 68
# ['English', 'French']                  35
# ['English', 'Japanese']                25
#                                      ...
# ['English /', 'Zulu']                   1
# ['English', 'Hebrew', 'Spanish']        1
# ['English', 'Japanese', 'French']       1
# ['English', 'Spanish', 'Apache']        1
# Russian                                 1
# Name: Language, Length: 198, dtype: int64

# %%
movies_df['original_language'].value_counts(dropna=False)
# Out:
# en    5987
# fr      16
# es      10
# it       8
# de       6
# ja       4
# pt       4
# zh       4
# da       2
# hi       2
# sv       1
# ko       1
# ab       1
# tr       1
# he       1
# ar       1
# cn       1
# ru       1
# Name: original_language, dtype: int64

# %%
movies_df[['Production company(s)','production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2             ['Carolco Pictures', 'IndieProd Company']
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                       ['Fabula', 'Komplizen Film']
# 6048                           Ball & Chain Productions
# 6049      ['Arte France Cinéma', 'Why Not Productions']
# 6050  ['Film Science', 'Rough House Pictures', 'Sync...
# 6051   ['HanWay Films', 'Little Punk', 'See-Saw Films']
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# ...

# %%
# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle             Drop Wiki
# running_time             runtime                  keep kaggle; fill in zeroes with wiki
# budget_wiki              budget_kaggle            keep kaggle; fill in zeroes with wiki
# box_office               revenue                  keep kaggle; fill in zeroes with wiki
# release_date_wiki        release_date_kaggle      Drop wiki
# Language                 original_language        Drop wiki
# Production company(s)    production_companies     Drop wiki

# %%
# drop wiki columns

movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10136/785526036.py in <module>
#       1 # drop wiki columns
#       2
# ----> 3 movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)
#
# NameError: name 'movies_df' is not defined

# %%
def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
        , axis=1)
    df.drop(columns=wiki_column, inplace=True)

# %%
fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')
fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')
fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')
movies_df
# Out:
#       Unnamed: 0                                                url  year  \
# 0              0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1              1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2              2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3              3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4              4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...          ...                                                ...   ...
# 6047        6837    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048        6844    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049        6849      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050        6888   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051        6925  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link  \
# ...

# %%
for col in movies_df.columns:
    lists_to_tuples = lambda x: tuple(x) if type(x) == list else x
    value_counts = movies_df[col].apply(lists_to_tuples).value_counts(dropna=False)
    num_values = len(value_counts)
    if num_values == 1:
        print(col)
# Out:
# video

# %%
movies_df['video'].value_counts(dropna=False)
# Out:
# False    6051
# Name: video, dtype: int64

# %%
[len(movies_df[col].apply(lambda x: tuple(x) if type(x) == list else x)) for col in movies_df]
# Out:
# [6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051,
#  6051]

# %%
movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on'
                      ]]

# %%
movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

# %%
movies_df
# Out:
#         imdb_id  kaggle_id                            title  \
# 0     tt0098987       9548  The Adventures of Ford Fairlane
# 1     tt0098994      25501             After Dark, My Sweet
# 2     tt0099005      11856                      Air America
# 3     tt0099012       8217                            Alice
# 4     tt0099018      25943                  Almost an Angel
# ...         ...        ...                              ...
# 6047  tt5639354     429191                A Fantastic Woman
# 6048  tt5390066     390059                       Permission
# 6049  tt6304162     429174                         Loveless
# 6050  tt5795086     412302                           Gemini
# 6051  tt3859310     341689  How to Talk to Girls at Parties
#
#                        original_title  \
# 0     The Adventures of Ford Fairlane
# 1                After Dark, My Sweet
# 2                         Air America
# 3                               Alice
# 4                     Almost an Angel
# ...

# %%
rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count()

# %%
rating_counts
# Out:
#         movieId               rating  userId  timestamp
# 0             1                 0.50     441        441
# 1             1                 1.00     804        804
# 2             1                 1.50     438        438
# 3             1                 2.00    2083       2083
# 4             1                 2.50    1584       1584
# ...         ...                  ...     ...        ...
# 239376   176267                 4.00       1          1
# 239377   176269                 3.50       1          1
# 239378   176271                 5.00       1          1
# 239379   176273                 1.00       1          1
# 239380   176275                 3.00       1          1
#
# [239381 rows x 4 columns]

# %%
rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1)

# %%
rating_counts
# Out:
#         movieId               rating  count  timestamp
# 0             1                 0.50    441        441
# 1             1                 1.00    804        804
# 2             1                 1.50    438        438
# 3             1                 2.00   2083       2083
# 4             1                 2.50   1584       1584
# ...         ...                  ...    ...        ...
# 239376   176267                 4.00      1          1
# 239377   176269                 3.50      1          1
# 239378   176271                 5.00      1          1
# 239379   176273                 1.00      1          1
# 239380   176275                 3.00      1          1
#
# [239381 rows x 4 columns]

# %%
rating_counts.columns = ['rating_' + str(col) for col in rating_counts.columns]

# %%
rating_counts
# Out:
#         rating_movieId        rating_rating  rating_count  rating_timestamp
# 0                    1                 0.50           441               441
# 1                    1                 1.00           804               804
# 2                    1                 1.50           438               438
# 3                    1                 2.00          2083              2083
# 4                    1                 2.50          1584              1584
# ...                ...                  ...           ...               ...
# 239376          176267                 4.00             1                 1
# 239377          176269                 3.50             1                 1
# 239378          176271                 5.00             1                 1
# 239379          176273                 1.00             1                 1
# 239380          176275                 3.00             1                 1
#
# [239381 rows x 4 columns]

# %%
movies_with_ratings_df = pd.merge(movies_df, rating_counts, left_on='kaggle_id', right_index=True, how='left')

# %%
movies_with_ratings_df
# Out:
#         imdb_id  kaggle_id                            title  \
# 0     tt0098987       9548  The Adventures of Ford Fairlane
# 1     tt0098994      25501             After Dark, My Sweet
# 2     tt0099005      11856                      Air America
# 3     tt0099012       8217                            Alice
# 4     tt0099018      25943                  Almost an Angel
# ...         ...        ...                              ...
# 6047  tt5639354     429191                A Fantastic Woman
# 6048  tt5390066     390059                       Permission
# 6049  tt6304162     429174                         Loveless
# 6050  tt5795086     412302                           Gemini
# 6051  tt3859310     341689  How to Talk to Girls at Parties
#
#                        original_title  \
# 0     The Adventures of Ford Fairlane
# 1                After Dark, My Sweet
# 2                         Air America
# 3                               Alice
# 4                     Almost an Angel
# ...

# %%
movies_with_ratings_df[rating_counts.columns] = movies_with_ratings_df[rating_counts.columns].fillna(0)

# %%
movies_with_ratings_df
# Out:
#         imdb_id  kaggle_id                            title  \
# 0     tt0098987       9548  The Adventures of Ford Fairlane
# 1     tt0098994      25501             After Dark, My Sweet
# 2     tt0099005      11856                      Air America
# 3     tt0099012       8217                            Alice
# 4     tt0099018      25943                  Almost an Angel
# ...         ...        ...                              ...
# 6047  tt5639354     429191                A Fantastic Woman
# 6048  tt5390066     390059                       Permission
# 6049  tt6304162     429174                         Loveless
# 6050  tt5795086     412302                           Gemini
# 6051  tt3859310     341689  How to Talk to Girls at Parties
#
#                        original_title  \
# 0     The Adventures of Ford Fairlane
# 1                After Dark, My Sweet
# 2                         Air America
# 3                               Alice
# 4                     Almost an Angel
# ...

# %%
# connect jupyter to postgres
db_string = f"postgresql://postgres:{password}@127.0.0.1:5432/movie_data"

# %%
# create database engine
engine = create_engine(db_string)

# %%
# import movie data
movies_df.to_sql(name='movies', con=engine)

# %%
# create a variable for the number of rows imported
rows_imported = 0
# get the start_time from time.time()
start_time = time.time()
for data in pd.read_csv(f'{kaggle_rating}', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='ratings', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000000...Done. 17.82419753074646 total seconds elapsed
# importing rows 1000000 to 2000000...Done. 35.30946183204651 total seconds elapsed
# importing rows 2000000 to 3000000...Done. 52.81353044509888 total seconds elapsed
# importing rows 3000000 to 4000000...Done. 70.28458499908447 total seconds elapsed
# importing rows 4000000 to 5000000...Done. 88.09448313713074 total seconds elapsed
# importing rows 5000000 to 6000000...Done. 106.25820183753967 total seconds elapsed
# importing rows 6000000 to 7000000...Done. 123.65548205375671 total seconds elapsed
# importing rows 7000000 to 8000000...Done. 141.24746799468994 total seconds elapsed
# importing rows 8000000 to 9000000...Done. 159.65605306625366 total seconds elapsed
# importing rows 9000000 to 10000000...Done. 177.72745871543884 total seconds elapsed
# importing rows 10000000 to 11000000...Done. 195.56454491615295 total seconds elapsed
# ...
